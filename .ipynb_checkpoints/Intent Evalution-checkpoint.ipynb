# %%
import pandas as pd

df = pd.read_csv("GenAI CS chatbot testing - Evaluation.csv")

# %% [markdown]
# ## Queries

# %% [markdown]
# ### Weirdly formatted queries
# - 10

# %%
print(df["Customer Query (Zendesk)"].iloc[30])
# Out:
# Transaction Ref. number (Optional):
#
# I made a transaction to Philippines but is not reflected at their end. Is there a proof of payment (such as a transaction reference number) from You Trip so that they can trace it?

# %% [markdown]
# ## Intents

# %%
df.columns
# Out:
# Index(['ID', 'Via Channel', 'Tags', 'User_ID', 'Category', 'Subcategory',
#        'Comment Count', 'Customer Query (Zendesk)',
#        'CS agent repsonse (Zendesk)', 'Intent classified by chatbot',
#        'chatbot response', 'Intent correct?', 'Response correct?', 'PIC',
#        'Further enhancement on this?', 'Remark', 'Suggested Intent',
#        'Intent Exclusion', 'RETEST?', 'RECHECKED?', 'Unnamed: 20',
#        'Unnamed: 21', 'RETEST on FRI?', 'Live Agent (Intent Y Response Y)'],
#       dtype='object')

# %%
df["Intent correct?"].value_counts()
# Out:
# Intent correct?
# Y    2843
# N     138
# Name: count, dtype: int64

# %%
df["Intent correct?"].isna().sum()
# Out:
# 1572

# %%
df[df["Intent correct?"]=="N"].head()
# Out:
#           ID Via Channel                                               Tags  \
# 44   1090061       email  1.8_others, card, payment___transaction_histor...
# 68   1089714       email    9.7_online_payment_, account, general_enquiries
# 73   1293507       email  5.6_top_up_authentication, b2c_youtrip, card, ...
# 126  1063102       email  3.2_delivery_status_for_approved_application, ...
# 155   792496       email  5.9_refund_with_fee, account, card, top_up, yo...
#
#        User_ID                             Category  \
# 44   1149956.0  payment___transaction_history__yes_
# 68   1072396.0                    general_enquiries
# 73     21073.0                               top_up
# 126  1063482.0                               top_up
# 155  1455568.0                               top_up
#
#                                       Subcategory  Comment Count  \
# 44                                     1.8_others              2
# 68                            9.7_online_payment_              2
# 73                      5.6_top_up_authentication              2
# 126  3.2_delivery_status_for_approved_application             14
# 155                           5.9_refund_with_fee              5
#
#                               Customer Query (Zendesk)  \
# 44   Hi, \n  Pls see attached transaction I had at ...
# 68   Hi,  \n  I wrote in to terminate my subscripti...
# 73   Hi,  \n  I’ve just changed my credit card deta...
# 126  Dear person in charge,\n\n \n \n \n \n\nI was ...
# 155  Hi I would like to refund all the current amou...
#
#                            CS agent repsonse (Zendesk)  \
# 44   Hi Jay Jin Jie,\n \nThank you for contacting Y...
# 68   Hi Chun Beng Koh,\n \nAs YouTrip is a major pa...
# 73   Hi Li Rong,\n \nThank you for contacting YouTr...
# 126  Hi Chee Wah,\n \nThank you for contacting YouT...
# 155  Hi Kuan Teng,\n \nThank you for contacting You...
#
#                           Intent classified by chatbot  ...  \
# 44     Support Request - Charged at a Different Amount  ...
# 68   Action Cancellation Request - Account Closure ...  ...
# 73              Support Request - Card Replacement Fee  ...
# 126        Action Request - Refund (Card Transactions)  ...
# 155        Action Request - Refund (Card Transactions)  ...
#
#     Further enhancement on this?        Remark  \
# 44                             Y  wrong intent
# 68                             Y  wrong intent
# 73                             Y  wrong intent
# 126                            Y  wrong intent
# 155                            Y  wrong intent
#
#                      Suggested Intent Intent Exclusion RETEST? RECHECKED?  \
# 44                                NaN                1     NaN        NaN
# 68   Action Request - ACCOUNT CLOSURE                0     NaN        NaN
# 73                        AUTH CHARGE                1     NaN        NaN
# 126                   BANK WITHDRAWAL                0     NaN        NaN
# 155                   BANK WITHDRAWAL                0     NaN         GK
#
#     Unnamed: 20  Unnamed: 21 RETEST on FRI? Live Agent (Intent Y Response Y)
# 44            1            1              1                         Not Live
# 68            1            1              1                         Not Live
# 73            1            1              1                         Not Live
# 126           1            1              1                         Not Live
# 155           1            1              1                         Not Live
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Standardize intent names of `Suggested Intent` columns

# %%
df_wrong_intent = df[df["Intent correct?"]=="N"]["Suggested Intent"]
df_wrong_intent
# Out:
# 44                                   NaN
# 68      Action Request - ACCOUNT CLOSURE
# 73                           AUTH CHARGE
# 126                      BANK WITHDRAWAL
# 155                      BANK WITHDRAWAL
#                       ...
# 3742                WRONG BILLING AMOUNT
# 3916                              OTHERS
# 3984                    EXPEDITE REQUEST
# 3985                              Petrol
# 4051                        REVERSED TXN
# Name: Suggested Intent, Length: 138, dtype: object

# %%
df_wrong_intent.isna().sum()
# Out:
# 11

# %%
df_wrong_intent = df_wrong_intent.dropna()
df_wrong_intent
# Out:
# 68      Action Request - ACCOUNT CLOSURE
# 73                           AUTH CHARGE
# 126                      BANK WITHDRAWAL
# 155                      BANK WITHDRAWAL
# 202                      BANK WITHDRAWAL
#                       ...
# 3742                WRONG BILLING AMOUNT
# 3916                              OTHERS
# 3984                    EXPEDITE REQUEST
# 3985                              Petrol
# 4051                        REVERSED TXN
# Name: Suggested Intent, Length: 127, dtype: object

# %%
intent_df = pd.read_csv("Parsing Intents.csv")
intent_list = intent_df["Intent Name"].to_list()

# %%
def clean_and_match_intents(row, intentCaptured):
    # Split by commas
    intents = row.split('\n')
    
    # Remove content inside parentheses for each part
    # print("row_intent:", intents) 
    

    cleaned_intents = []
    for intent in intents:
        intent = intent.split('(')[0].strip().lower()
        cleaned_intents.append(intent)

        
        # To also match with intents with '/'
        for intent_ in intent.split('/'):
            intent_ = intent_.strip().lower()
            cleaned_intents.append(intent_)
    # print("cleaned_intents:", cleaned_intents)

    # Check if the captured intent matches any cleaned intent
    intentCaptured = intentCaptured.split("-")[-1].split('(')[0].strip().lower()
    # print("intentCaptured:", cleaned_intents)
    return intentCaptured in cleaned_intents
    
# wrong_intent = df_wrong_intent.iloc[0]
wrong_intent = "Action Request - Account Closure / Suspension / Frozen"

print("Intent:")
print(wrong_intent)
filtered_intent = intent_df[intent_df['Intent Name'].apply(clean_and_match_intents, intentCaptured=wrong_intent)]
filtered_intent
# Out:
# Intent:
# Action Request - Account Closure / Suspension / Frozen
#                               Intent Name
# 15  Account Closure / Suspension / Frozen

# %%
df[df["Intent correct?"]=="N"].head()
# Out:
#           ID Via Channel                                               Tags  \
# 44   1090061       email  1.8_others, card, payment___transaction_histor...
# 68   1089714       email    9.7_online_payment_, account, general_enquiries
# 73   1293507       email  5.6_top_up_authentication, b2c_youtrip, card, ...
# 126  1063102       email  3.2_delivery_status_for_approved_application, ...
# 155   792496       email  5.9_refund_with_fee, account, card, top_up, yo...
#
#        User_ID                             Category  \
# 44   1149956.0  payment___transaction_history__yes_
# 68   1072396.0                    general_enquiries
# 73     21073.0                               top_up
# 126  1063482.0                               top_up
# 155  1455568.0                               top_up
#
#                                       Subcategory  Comment Count  \
# 44                                     1.8_others              2
# 68                            9.7_online_payment_              2
# 73                      5.6_top_up_authentication              2
# 126  3.2_delivery_status_for_approved_application             14
# 155                           5.9_refund_with_fee              5
#
#                               Customer Query (Zendesk)  \
# 44   Hi, \n  Pls see attached transaction I had at ...
# 68   Hi,  \n  I wrote in to terminate my subscripti...
# 73   Hi,  \n  I’ve just changed my credit card deta...
# 126  Dear person in charge,\n\n \n \n \n \n\nI was ...
# 155  Hi I would like to refund all the current amou...
#
#                            CS agent repsonse (Zendesk)  \
# 44   Hi Jay Jin Jie,\n \nThank you for contacting Y...
# 68   Hi Chun Beng Koh,\n \nAs YouTrip is a major pa...
# 73   Hi Li Rong,\n \nThank you for contacting YouTr...
# 126  Hi Chee Wah,\n \nThank you for contacting YouT...
# 155  Hi Kuan Teng,\n \nThank you for contacting You...
#
#                           Intent classified by chatbot  ...  \
# 44     Support Request - Charged at a Different Amount  ...
# 68   Action Cancellation Request - Account Closure ...  ...
# 73              Support Request - Card Replacement Fee  ...
# 126        Action Request - Refund (Card Transactions)  ...
# 155        Action Request - Refund (Card Transactions)  ...
#
#     Further enhancement on this?        Remark  \
# 44                             Y  wrong intent
# 68                             Y  wrong intent
# 73                             Y  wrong intent
# 126                            Y  wrong intent
# 155                            Y  wrong intent
#
#                      Suggested Intent Intent Exclusion RETEST? RECHECKED?  \
# 44                                NaN                1     NaN        NaN
# 68   Action Request - ACCOUNT CLOSURE                0     NaN        NaN
# 73                        AUTH CHARGE                1     NaN        NaN
# 126                   BANK WITHDRAWAL                0     NaN        NaN
# 155                   BANK WITHDRAWAL                0     NaN         GK
#
#     Unnamed: 20  Unnamed: 21 RETEST on FRI? Live Agent (Intent Y Response Y)
# 44            1            1              1                         Not Live
# 68            1            1              1                         Not Live
# 73            1            1              1                         Not Live
# 126           1            1              1                         Not Live
# 155           1            1              1                         Not Live
#
# [5 rows x 24 columns]

# %%
dataset_df = df.copy()
dataset_df = dataset_df.dropna(subset=['Intent correct?'])
dataset_df.isna().sum()
# Out:
# ID                                     0
# Via Channel                            0
# Tags                                   0
# User_ID                                0
# Category                              17
# Subcategory                           11
# Comment Count                          0
# Customer Query (Zendesk)               0
# CS agent repsonse (Zendesk)            2
# Intent classified by chatbot          18
# chatbot response                      11
# Intent correct?                        0
# Response correct?                    194
# PIC                                    1
# Further enhancement on this?         191
# Remark                              2513
# Suggested Intent                    2829
# Intent Exclusion                       0
# RETEST?                             2880
# RECHECKED?                          2427
# Unnamed: 20                            0
# Unnamed: 21                            0
# RETEST on FRI?                         0
# Live Agent (Intent Y Response Y)       0
# dtype: int64

# %%
dataset_df['True Intent'] = None

# %%
dataset_df.columns
# Out:
# Index(['ID', 'Via Channel', 'Tags', 'User_ID', 'Category', 'Subcategory',
#        'Comment Count', 'Customer Query (Zendesk)',
#        'CS agent repsonse (Zendesk)', 'Intent classified by chatbot',
#        'chatbot response', 'Intent correct?', 'Response correct?', 'PIC',
#        'Further enhancement on this?', 'Remark', 'Suggested Intent',
#        'Intent Exclusion', 'RETEST?', 'RECHECKED?', 'Unnamed: 20',
#        'Unnamed: 21', 'RETEST on FRI?', 'Live Agent (Intent Y Response Y)',
#        'True Intent'],
#       dtype='object')

# %%
for i, row in dataset_df.iterrows():
    try: 
        if row['Intent correct?'] == "Y" and pd.notna(row["Intent classified by chatbot"]):
            # print(row["Intent classified by chatbot"])
            suggested_intent = intent_df[intent_df['Intent Name'].apply(clean_and_match_intents, intentCaptured=row["Intent classified by chatbot"])]
            if len(suggested_intent['Intent Name'])<1:
                print("Intent Correct (Y) but no matching intent:")
                print(row["Intent classified by chatbot"])
                continue
            suggested_intent = suggested_intent['Intent Name'].iloc[0]
            # print(suggested_intent)
            dataset_df.loc[i, 'True Intent'] = suggested_intent
    
        if row['Intent correct?'] == "N" and pd.notna(row['Suggested Intent']):
            print("wrong intent-")

            suggested_intent = intent_df[intent_df['Intent Name'].apply(clean_and_match_intents, intentCaptured=row["Suggested Intent"])]
            if len(suggested_intent['Intent Name'])<1:
                print("Intent Incorrect (N) but no matching intent:")
                print(row["Suggested Intent"])
                continue
            suggested_intent = suggested_intent['Intent Name'].iloc[0]
            # print(suggested_intent)
            dataset_df.loc[i, 'True Intent'] = suggested_intent
    except Exception as e:
        print(row)
        raise Exception(str(e))
# Out:
# Intent Correct (Y) but no matching intent:
# Action Cancellation Request - Action Cancellation Request
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Surprise Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Navigation Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Action Request - Card Removal from Mobile Wallet
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# AUTH CHARGE
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# BANK WITHDRAWAL
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# BANK WITHDRAWAL
# Intent Correct (Y) but no matching intent:
# Support Request - Card Unsuspension
# Intent Correct (Y) but no matching intent:
# Information Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Action Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Support Request - Missing Topup
# Intent Correct (Y) but no matching intent:
# Action Cancellation Request - Action Cancellation Request
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# BANK WITHDRAWAL
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# AUTH CHARGE
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# BUS/ MRT
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Information Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Support Request - MRT & Bus Transaction (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Inquiry - YouTrip Perks Cashback
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - Missing Topup
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - Card Limit
# Intent Correct (Y) but no matching intent:
# Support Request - Exchange Rate (Incorrect Rate)
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - In-App Form Issues
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Support Request - App Issues
# wrong intent-
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Action Request - Bank Withdrawls or Refund to Bank Account or Transfer Money Out
# wrong intent-
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Action Request - Bank Withdrawls
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Action Request - Wrong P2P Transaction
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Surprise Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Surprise Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - Missing Topup
# Intent Correct (Y) but no matching intent:
# Support Request - Missing Topup
# Intent Correct (Y) but no matching intent:
# Action Request - Bank / Wire Transfer
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - Missing / Pending P2P
# Intent Correct (Y) but no matching intent:
# Feedback - YouTrip Surprise Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Action Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - Missing Topup
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# DECLINED TXN
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# DECLINED TXN
# Intent Correct (Y) but no matching intent:
# Support Request - Account Suspension
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Navigation Request - Bank / Wire Transfer
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# P2P issue
# Intent Correct (Y) but no matching intent:
# Support Request - Virtual Card Payment (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Surprise Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - Missing Topup
# Intent Correct (Y) but no matching intent:
# Support Request - Missing Topup
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# DECLINED TXN
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Feedback - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# DECLINED TXN
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# DUPLICATE
# Intent Correct (Y) but no matching intent:
# Support Request - In-App Form Issues
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# DUPLICATE
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# DUPLICATE
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# EXCHANGE
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# EXPEDITE REQUEST
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Surprise Cashback
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# EXPEDITE REQUEST
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# EXPEDITE REQUEST
# Intent Correct (Y) but no matching intent:
# Support Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# EXPEDITE REQUEST
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# EXPEDITE REQUEST
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# EXPEDITE REQUEST
# Intent Correct (Y) but no matching intent:
# Action Cancellation Request - Recurring Charge
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# FEEDBACK
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# FEEDBACK
# Intent Correct (Y) but no matching intent:
# Action Request - Card Suspension / Reactivation
# Intent Correct (Y) but no matching intent:
# Support Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Support Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# FEEDBACK
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# FEEDBACK
# Intent Correct (Y) but no matching intent:
# Information Request - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# GENERAL ENQUIRY
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# GENERAL ENQUIRY
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PRIVACY
# Intent Correct (Y) but no matching intent:
# Support Request - Exchange Rate (Incorrect Rate)
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PRIVACY
# Intent Correct (Y) but no matching intent:
# Action Request - Exchange Rate (Incorrect Rate)
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# GERNAL ENQUIRY
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# LIMIT
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# Action Request
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Support Request - Virtual Card Payment (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Support Request - Virtual Card Payment (General Enquiry)
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Support Request - Virtual Card Payment (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Information Request - Account Reapply / Reactivation / Unsuspension / Unfreeze / Reinstatement / re signup
# Intent Correct (Y) but no matching intent:
# Support Request - Top Up
# Intent Correct (Y) but no matching intent:
# Support Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Support Request - In-App Form Issues
# wrong intent-
# wrong intent-
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# General Enquiry
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# wrong intent-
# wrong intent-
# wrong intent-
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# GERNAL ENQUIRY
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# wrong intent-
# wrong intent-
# wrong intent-
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PETROL
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Action Request - Bank / Wire Transfer
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PRIVACY
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# CARD REPLACEMENT NO FRAUD
# wrong intent-
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Cancellation Request - Recurring Transaction Cancellation
# wrong intent-
# wrong intent-
# wrong intent-
# wrong intent-
# wrong intent-
# wrong intent-
# wrong intent-
# wrong intent-
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - App Login Issue
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Support Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Support Request - MRT & Bus Transaction (General Enquiry)
# wrong intent-
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNSUSPEND
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Support Request - WeChat Pay Payment Issue
# Intent Correct (Y) but no matching intent:
# Information Request - Virtual Card Payment (General Enquiry)
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PETROL
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PETROL
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# GERNAL ENQUIRY
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PETROL
# Intent Correct (Y) but no matching intent:
# Support Request - MRT & Bus Transaction (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Action Request - Wrong P2P Transaction
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PIN RESET
# wrong intent-
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PRODUCT FEATURE
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Support Request - Exchange Rate (Multiple Currency Conversions)
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# Support Request - Account Suspension
# Intent Correct (Y) but no matching intent:
# Information Request - Card Usage
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Information Request - Foreign Currency Topup
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# PROMOCODE
# wrong intent-
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REFUND GENERAL QN?
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Cancellation Request - Ride-hailing Payment (Reverse Status)
# Intent Correct (Y) but no matching intent:
# Support Request - Virtual Card Payment (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Information Request - Card Limit
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Information Request - Topup
# Intent Correct (Y) but no matching intent:
# Support Request - MRT & Bus Transaction (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Support Request - Exchange Rate (General Enquiry)
# wrong intent-
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - Account Reactivation / Revalidation / Unsuspension
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REINSTATE
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REINSTATE
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# FEEDBACK
# Intent Correct (Y) but no matching intent:
# Support Request - Pending / Missing P2P
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REINSTATE
# Intent Correct (Y) but no matching intent:
# Action Cancellation Request - Action Cancellation Request
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# DECLINED TXN
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REINSTATE
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REINSTATE
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - Virtual Card Payment (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Support Request - PayPal Payment Issue
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REINSTATE
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REINSTATE
# Intent Correct (Y) but no matching intent:
# Information Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Support Request - Exchange Rate (Incorrect Rate)
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# RESET PIN
# Intent Correct (Y) but no matching intent:
# Support Request - Card Limit
# wrong intent-
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNRECOGNISED TXN
# Intent Correct (Y) but no matching intent:
# Action Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Support Request - In-App Form Issues
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Information Request - Virtual Card Payment (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Bank / Wire Transfer
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# Intent Correct (Y) but no matching intent:
# Feedback - YouTrip Perks Cashback
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# RETAINED IN ATM
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNREGCONISED
# Intent Correct (Y) but no matching intent:
# Feedback - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Bank Withdrawls
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# VAGUE
# Intent Correct (Y) but no matching intent:
# Support Request - App Issues
# Intent Correct (Y) but no matching intent:
# Support Request - Exchange Rate (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Action Request - Account Reactivation / Unsuspension / Unfreeze / Reinstatement
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# TECHNICAL
# wrong intent-
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNRECOGNISED
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNRECOGNISED
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNRECOGNISED
# Intent Correct (Y) but no matching intent:
# Support Request - Account Suspension / Frozen
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNRECOGNISED
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# GENERAL ENQUIRY
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# ???
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNRECOGNISED
# Intent Correct (Y) but no matching intent:
# Support Request - Technical Error
# Intent Correct (Y) but no matching intent:
# Support Request - In-App Form Issues
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNRECOGNISED
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# UNSUSPEND
# wrong intent-
# Intent Correct (Y) but no matching intent:
# Support Request - In-App Form Issues
# wrong intent-
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# EXPEDITE REQUEST
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# Petrol
# wrong intent-
# Intent Incorrect (N) but no matching intent:
# REVERSED TXN
# Intent Correct (Y) but no matching intent:
# Support Request - Technical Error
# Intent Correct (Y) but no matching intent:
# Support Request - Account Reactivation / Reinstatement / Unsuspension / Unfreeze / Resigning
# Intent Correct (Y) but no matching intent:
# Support Request - Virtual Card Payment (General Enquiry)
# Intent Correct (Y) but no matching intent:
# Support Request - General Enquiry

# %%
dataset_df.isna().sum()
# Out:
# ID                                     0
# Via Channel                            0
# Tags                                   0
# User_ID                                0
# Category                              17
# Subcategory                           11
# Comment Count                          0
# Customer Query (Zendesk)               0
# CS agent repsonse (Zendesk)            2
# Intent classified by chatbot          18
# chatbot response                      11
# Intent correct?                        0
# Response correct?                    194
# PIC                                    1
# Further enhancement on this?         191
# Remark                              2513
# Suggested Intent                    2829
# Intent Exclusion                       0
# RETEST?                             2880
# RECHECKED?                          2427
# Unnamed: 20                            0
# Unnamed: 21                            0
# RETEST on FRI?                         0
# Live Agent (Intent Y Response Y)       0
# True Intent                          303
# dtype: int64

# %%
dataset_df.head()
# Out:
#         ID Via Channel                                               Tags  \
# 0  1090222       email  1.2_pending_or_reversed_transaction, card, pay...
# 1  1090221         api  4.4_unable_to_log_in, category:login_activatio...
# 2  1090218       email  11.12__socialmedia__apple_pay/google_pay_issue...
# 3  1090209       email  6.1_request_to_change_mobile_number, card, per...
# 4  1090205         api  3.2_delivery_status_for_approved_application, ...
#
#      User_ID                             Category  \
# 0  1600322.0  payment___transaction_history__yes_
# 1  1426815.0                   login___activation
# 2  1314226.0                    general_enquiries
# 3  1540919.0                     personal_details
# 4  2013816.0         sign_up___application_status
#
#                                        Subcategory  Comment Count  \
# 0              1.2_pending_or_reversed_transaction              2
# 1                             4.4_unable_to_log_in              4
# 2  11.12__socialmedia__apple_pay/google_pay_issues              4
# 3              6.1_request_to_change_mobile_number              6
# 4     3.2_delivery_status_for_approved_application              2
#
#                             Customer Query (Zendesk)  \
# 0  Hi there, I tried to book the Alcatraz tour ye...
# 1                   Unable to log in on my new phone
# 2  Dear YouTrip, \n This is the second time that ...
# 3  Hi,  \n  I am a Malaysian that no longer worki...
# 4  Hi, i applied for youtrip physical card on 17 ...
#
#                          CS agent repsonse (Zendesk)  \
# 0  Hi Kim,\n \nThank you for contacting YouTrip!\...
# 1  Hi Gunasilan,\n \nThank you for contacting You...
# 2  Hi Wei Xiong,\n \nThank you for contacting You...
# 3  Thank you for your clarification, Kah Hoe.\n \...
# 4  Hi Ruth,\n \nThank you for contacting YouTrip!...
#
#                         Intent classified by chatbot  ...         Remark  \
# 0       Support Request - Refund (Card Transactions)  ...            NaN
# 1                     Support Request - Log In Error  ...  live agent UI
# 2          Support Request - Apple Pay Payment Issue  ...            NaN
# 3  Action Request - Account Closure / Suspension ...  ...            NaN
# 4         Information Request - Card Delivery Status  ...            NaN
#
#   Suggested Intent Intent Exclusion RETEST?      RECHECKED? Unnamed: 20  \
# 0              NaN                0     NaN             NaN           0
# 1              NaN                0     NaN  TE - Avanthika           0
# 2              NaN                1     NaN  TE - Avanthika           0
# 3              NaN                0     NaN             NaN           0
# 4              NaN                0     NaN        Jennifer           0
#
#   Unnamed: 21  RETEST on FRI? Live Agent (Intent Y Response Y)  \
# 0           0               0                             Live
# 1           1               1                         Not Live
# 2           0               0                             Live
# 3           0               0                         Not Live
# 4           0               0                         Not Live
#
#                              True Intent
# 0               Refund (General Enquiry)
# 1                           Log In Error
# 2                Apple Pay Payment Issue
# 3  Account Closure / Suspension / Frozen
# 4                   Card Delivery Status
#
# [5 rows x 25 columns]

# %%
dataset_df.isna().sum()
# Out:
# ID                                     0
# Via Channel                            0
# Tags                                   0
# User_ID                                0
# Category                              17
# Subcategory                           11
# Comment Count                          0
# Customer Query (Zendesk)               0
# CS agent repsonse (Zendesk)            2
# Intent classified by chatbot          18
# chatbot response                      11
# Intent correct?                        0
# Response correct?                    194
# PIC                                    1
# Further enhancement on this?         191
# Remark                              2513
# Suggested Intent                    2829
# Intent Exclusion                       0
# RETEST?                             2880
# RECHECKED?                          2427
# Unnamed: 20                            0
# Unnamed: 21                            0
# RETEST on FRI?                         0
# Live Agent (Intent Y Response Y)       0
# True Intent                          303
# dtype: int64

# %%
# Which category of intent correct does not have matching true intent
dataset_df[dataset_df['True Intent'].isna()]['Intent correct?'].value_counts()
# Out:
# Intent correct?
# Y    218
# N     85
# Name: count, dtype: int64

# %%
dataset_df.isna().sum()
# Out:
# ID                                     0
# Via Channel                            0
# Tags                                   0
# User_ID                                0
# Category                              17
# Subcategory                           11
# Comment Count                          0
# Customer Query (Zendesk)               0
# CS agent repsonse (Zendesk)            2
# Intent classified by chatbot          18
# chatbot response                      11
# Intent correct?                        0
# Response correct?                    194
# PIC                                    1
# Further enhancement on this?         191
# Remark                              2513
# Suggested Intent                    2829
# Intent Exclusion                       0
# RETEST?                             2880
# RECHECKED?                          2427
# Unnamed: 20                            0
# Unnamed: 21                            0
# RETEST on FRI?                         0
# Live Agent (Intent Y Response Y)       0
# True Intent                          303
# dtype: int64

# %%
dataset_df = dataset_df.dropna(subset=["True Intent"])

# %%
dataset_df.isna().sum()
# Out:
# ID                                     0
# Via Channel                            0
# Tags                                   0
# User_ID                                0
# Category                              13
# Subcategory                            9
# Comment Count                          0
# Customer Query (Zendesk)               0
# CS agent repsonse (Zendesk)            2
# Intent classified by chatbot           1
# chatbot response                       1
# Intent correct?                        0
# Response correct?                    168
# PIC                                    1
# Further enhancement on this?         165
# Remark                              2309
# Suggested Intent                    2603
# Intent Exclusion                       0
# RETEST?                             2581
# RECHECKED?                          2183
# Unnamed: 20                            0
# Unnamed: 21                            0
# RETEST on FRI?                         0
# Live Agent (Intent Y Response Y)       0
# True Intent                            0
# dtype: int64

# %% [markdown]
# ## Trigger Intent Agent

# %%
import boto3
from dotenv import load_dotenv

load_dotenv()

ACCESS_KEY = 'AKIA5Q7BAXIX2FVSCVMN'  
SECRET_KEY = os.environ['sec2']

# Replace this with the actual ARN of the Data Team Role
ROLE_ARN = "arn:aws:iam::929795455535:role/aws-datateam-readwrite-role"

# Session name can be any identifier string
SESSION_NAME = 'assume-data-team-role'

# Use your own credentials to create the STS client
sts_client = boto3.client('sts',
    aws_access_key_id=ACCESS_KEY,
    aws_secret_access_key=SECRET_KEY,
)

# Assume the role
response = sts_client.assume_role(
    RoleArn=ROLE_ARN,
    RoleSessionName=SESSION_NAME
)

# Extract temporary credentials
temp_credentials = response['Credentials']

# You can now use these to access resources as that role
assumed_session = boto3.Session(
    aws_access_key_id=temp_credentials['AccessKeyId'],
    aws_secret_access_key=temp_credentials['SecretAccessKey'],
    aws_session_token=temp_credentials['SessionToken'],
)

# Example: use this session to invoke Lambda
lambda_client = assumed_session.client('lambda', region_name='ap-southeast-1')

lambda_client_no_data_role = boto3.client('lambda',
                      aws_access_key_id=ACCESS_KEY,
                      aws_secret_access_key=SECRET_KEY)



# ----

# ACCESS_KEY = 'AKIA5Q7BAXIX2FVSCVMN'  
# SECRET_KEY = os.environ['sec2']

# ROLE_NAME = "arn:aws:iam::929795455535:role/aws-datateam-readwrite-role"


# client = boto3.client('lambda',
#                       aws_access_key_id=ACCESS_KEY,
#                       aws_secret_access_key=SECRET_KEY)

# %%
# Utils

import json 
import boto3
import re
import asyncio
import logging



def decode_response_json(AgentResponse):
    AgentResponse = f"""{AgentResponse}""" 
    AgentResponse = extract_json_string(AgentResponse)
    AgentResponse = fix_missing_commas(AgentResponse)
    AgentResponse = escape_json_string(AgentResponse)
    try:
        dic = json.loads(AgentResponse, strict=False)
    except json.decoder.JSONDecodeError:
        raise Exception(f"JSON decoding failed: {str(AgentResponse)}")
    return dic


def extract_json_string(response):
    json_start = None
    brace_count = 0
    json_str = ""

    # Iterate through the string to find JSON object
    for i, char in enumerate(response):
        if char == '{' and (i == 0 or response[i - 1] != '\\'):
            if json_start is None:
                json_start = i
            brace_count += 1
        
        elif char == '}' and (i == 0 or response[i - 1] != '\\'):
            brace_count -= 1
        
        if json_start is not None:
            json_str += char
        
        if brace_count == 0 and json_start is not None:
            break
    
    # If no valid JSON was found
    if not json_str:
        return "Invalid response: No valid JSON object found."
    
    return json_str


def fix_missing_commas(input_string):
    result = re.sub(r'"\s*"INFO_', '",\n"INFO_', input_string)
    return result


def escape_json_string(json_string):
    try:
        dic = json.loads(json_string, strict=False)
        return json_string 
    except json.decoder.JSONDecodeError:
        escaped_string = escape_quotes(json_string)
        return escaped_string


def escape_quotes(input_string):
    # This function will replace any double quotes inside a value with escaped quotes
    def escape_inside_quotes(value):
        return value.replace('"', '\\"')
    input_string = re.sub(r'"\s*"INFO_', '",\n"INFO_', input_string)

    # Regular expression to match JSON-like values inside double quotes after a colon
    # This pattern captures everything between the double quotes
    pattern = r'(?<=:\s)"(.*?)"(?=\s*(\}|,\s*(?![a-zA-Z])[\s\n]*?(?=")))'
    
    # Apply the escape function to the matches found, including multiline support
    result = re.sub(pattern, 
                    lambda match: '"' + escape_inside_quotes(match.group(1)) + '"',
                    input_string, 
                    flags=re.DOTALL)
    
    return result


def intent_check(main_string, substrings):
    main_string = main_string.lower()
    return any(substring in main_string for substring in substrings)


def validate_response_data(data, required_fields):
    if not data:
        raise ValueError("No Data Provided")

    for field in required_fields:
        if field not in data:
            raise ValueError(f"Missing required field: {field}\n\n{data}")
    return data

# %%
import time
import requests
import json
import random
import re



def invoke_intent_agent(uid, question):
    payload = {
      "uid": str(uid),
      "userInput": question,
      "intentCaptured": "",
      "lastIntent": "",
      "convoHistory": [],
      "fna": ":CS_Testing",
    }
    
    try:
        # Send a POST request to the Function URL
        retry_counter = 0
        while retry_counter <3:
            AgentResponse = lambda_client.invoke(
                FunctionName="u-data-TripGPT-Agent-Intent"+payload['fna'],
                InvocationType="RequestResponse",  # synchronous
                Payload=json.dumps(payload),
            )

            pl = json.load(AgentResponse['Payload'])
            if 'FunctionError' not in AgentResponse:
                # result = response.json()
                
     
                # result.update(json.loads(result['Status']))

                pl = validate_response_data(pl, required_fields=["IntentAgentResponse", "PromptToIntentAgent"])
                IntentAgentResponse = pl['IntentAgentResponse']
                PromptToIntentAgent = pl['PromptToIntentAgent']
                
                try:
                    dic = decode_response_json(IntentAgentResponse)
                except Exception as e:
                    print(e)
                    return IntentAgentResponse   
            
                dic = validate_response_data(dic, required_fields=["INFO_1", "INFO_2", "INFO_3"])
                temp_intent_captured = dic['INFO_1']
                cl = dic['INFO_2']
                rq = dic ['INFO_3']
            
                try:
                    cl = int(cl)
                except ValueError:
                    cl = 0
            
                if cl<=82:
                    fuq = dic['INFO_4']
                    chatbot_response = fuq
                    intent_captured = ''
                else:
                    intent_captured = temp_intent_captured
                    fuq=''
                return intent_captured
            else:
                retry_counter += 1       
                time.sleep(random.uniform(2, 5))
                
            return {"error": f"Error: Received error:  {AgentResponse}"}
    except requests.exceptions.RequestException as e:
        return {"error": f"Error: Received status code {AgentResponse}"}

# %%
# %%time
output = invoke_intent_agent(123098, "I don konw my card")
# Out:
# CPU times: user 31.9 ms, sys: 12.7 ms, total: 44.5 ms
# Wall time: 5.86 s

# %%
output
# Out:
# 'Support Request - Card Activation'

# %%
invoke_intent_agent(123098, "helloo")
# Out:
# {'error': 'Error: Received status code 502'}

# %% [markdown]
# ## Benchmark Baseline

# %%
# Which category of intent correct does not have matching true intent
dataset_df['Intent correct?'].value_counts()
# Out:
# Intent correct?
# Y    2625
# N      53
# Name: count, dtype: int64

# %%
dataset_df.columns
# Out:
# Index(['ID', 'Via Channel', 'Tags', 'User_ID', 'Category', 'Subcategory',
#        'Comment Count', 'Customer Query (Zendesk)',
#        'CS agent repsonse (Zendesk)', 'Intent classified by chatbot',
#        'chatbot response', 'Intent correct?', 'Response correct?', 'PIC',
#        'Further enhancement on this?', 'Remark', 'Suggested Intent',
#        'Intent Exclusion', 'RETEST?', 'RECHECKED?', 'Unnamed: 20',
#        'Unnamed: 21', 'RETEST on FRI?', 'Live Agent (Intent Y Response Y)',
#        'True Intent'],
#       dtype='object')

# %%
for i, row in dataset_df.iterrows():
    try: 
        uid = row['User_ID']
        query = row['Customer Query (Zendesk)']

        predicted_intent = invoke_intent_agent(123098, query)
        print(query)
        print(predicted_intent)

        matched_intent = intent_df[intent_df['Intent Name'].apply(clean_and_match_intents, intentCaptured=predicted_intent)]
        print(matched_intent)

        print(row["True Intent"])

        clean_and_match_intents(row[matched_intent
        print("====================")
        if i > 5:
            break
        # if row['Intent correct?'] == "Y" and pd.notna(row["Intent classified by chatbot"]):
        #     # print(row["Intent classified by chatbot"])
        #     suggested_intent = intent_df[intent_df['Intent Name'].apply(clean_and_match_intents, intentCaptured=row["Intent classified by chatbot"])]
        #     if len(suggested_intent['Intent Name'])<1:
        #         print("Intent Correct (Y) but no matching intent:")
        #         print(row["Intent classified by chatbot"])
        #         continue
        #     suggested_intent = suggested_intent['Intent Name'].iloc[0]
        #     # print(suggested_intent)
        #     dataset_df.loc[i, 'True Intent'] = suggested_intent
    
        # if row['Intent correct?'] == "N" and pd.notna(row['Suggested Intent']):
        #     print("wrong intent-")

        #     suggested_intent = intent_df[intent_df['Intent Name'].apply(clean_and_match_intents, intentCaptured=row["Suggested Intent"])]
        #     if len(suggested_intent['Intent Name'])<1:
        #         print("Intent Incorrect (N) but no matching intent:")
        #         print(row["Suggested Intent"])
        #         continue
        #     suggested_intent = suggested_intent['Intent Name'].iloc[0]
        #     # print(suggested_intent)
        #     dataset_df.loc[i, 'True Intent'] = suggested_intent
    except Exception as e:
        print(f"Problam at row: {i}: {e}\n{row}")
# Out:
# Hi there, I tried to book the Alcatraz tour yesterday with my Youtrip card but not successful due to card registered address. However, there is a pending agency charge of US$24 in my card balance for the said transaction.
#   Please look into it and help to reverse the entry.
#   RD~AUSTIN~78739 TX 840USD 24.00Ref. No: SFT-361864273
#   Many thanks.
#   Kind regards
#   Chan Kim Kooi
#  Sent from my iPad
# Support Request - Pending Transaction (Reversal of Pending Transaction)
#                                           Intent Name
# 24              Pending Transaction (General Enquiry)
# 25  Pending Transaction (Reversal of Pending Trans...
# Refund (General Enquiry)
# ====================
# Unable to log in on my new phone
# Support Request - Log In Error
#      Intent Name
# 98  Log In Error
# Log In Error
# ====================
# Dear YouTrip,
#  This is the second time that I have received this email from you. I have not made any requested to remove Apple Pay, kindly please check! Thank you.
#  Sent from my iPhone
#
#
#
#
#  Regards,
#  Jeffrey Then
# Support Request - Mobile Wallet Issue
#             Intent Name
# 61  Mobile Wallet Issue
# Apple Pay Payment Issue
# ====================
# Hi,
#   I am a Malaysian that no longer working in Singapore.  I do not have Singapore phone number anymore.
#   Should I cancel my card or could I keep it?
#   Thanks
# Action Request - Account Closure / Suspension / Frozen
#                               Intent Name
# 15  Account Closure / Suspension / Frozen
# Account Closure / Suspension / Frozen
# ====================
# Hi, i applied for youtrip physical card on 17 Dec but it has been over 2 weeks and my card has not been delivered. Would like to enquire on the delivery status
# Support Request - Card Delivery Status
#             Intent Name
# 1  Card Delivery Status
# Card Delivery Status
# ====================

# %%
import sklearn
